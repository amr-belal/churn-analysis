# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_excel("Churn_Modelling.xlsx")

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.drop(columns="RowNumber",axis=1 , inplace=True)

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
exited=data["EstimatedSalary"]

# %%
data.drop(columns="EstimatedSalary",axis=1 , inplace=True)

# %%
data["EstimatedSalary"]=exited

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  Exited  \
# 0       0.00              1          1               1       1
# 1   83807.86              1          0               1       0
# 2  159660.80              3          1               0       1
# 3       0.00              2          0               0       0
# 4  125510.82              1          1               1       0
#
#    EstimatedSalary
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4         79084.10

# %%
data["Balance"].replace(0.00,np.nan,inplace=True)

# %%
data.isnull().sum()
# Out:
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance            3617
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# Exited                0
# EstimatedSalary       0
# dtype: int64

# %%
data["Balance"].replace(np.nan,np.mean(data["Balance"]),inplace=True)

# %%
data.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# Exited             0
# EstimatedSalary    0
# dtype: int64

# %%
data["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

lb=LabelEncoder()
data["Gender"]=lb.fit_transform(data["Gender"])

# %%
from sklearn.preprocessing import OneHotEncoder
oh = OneHotEncoder(sparse_output=False)
Geography_dataframe = oh.fit_transform(data[['Geography']])
Geography_dataframe
# Out:
# array([[1., 0., 0.],
#        [0., 0., 1.],
#        [1., 0., 0.],
#        ...,
#        [1., 0., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.]])

# %%
for e , (val , _) in enumerate(values.items()):
    data["region_" + str(val)] = part[:,e]

data = data.drop(["region"] , axis = 1)

data.head()

# %%
Geography_dataframe=pd.DataFrame(Geography_dataframe)

# %%
Geography_dataframe.rename({0:'France', 1:'Germany', 2:'Spain'}, axis=1, inplace=True)

# %%
data = pd.concat([Geography_dataframe, data], axis=1)
data
# Out:
#       France  Germany  Spain  CustomerId    Surname  CreditScore Geography  \
# 0        1.0      0.0    0.0    15634602   Hargrave          619    France
# 1        0.0      0.0    1.0    15647311       Hill          608     Spain
# 2        1.0      0.0    0.0    15619304       Onio          502    France
# 3        1.0      0.0    0.0    15701354       Boni          699    France
# 4        0.0      0.0    1.0    15737888   Mitchell          850     Spain
# ...      ...      ...    ...         ...        ...          ...       ...
# 9995     1.0      0.0    0.0    15606229   Obijiaku          771    France
# 9996     1.0      0.0    0.0    15569892  Johnstone          516    France
# 9997     1.0      0.0    0.0    15584532        Liu          709    France
# 9998     0.0      1.0    0.0    15682355  Sabbatini          772   Germany
# 9999     1.0      0.0    0.0    15628319     Walker          792    France
#
# ...

# %%
data.drop("Surname",axis=1,inplace=True)

# %%
data
# Out:
#       France  Germany  Spain  CustomerId  CreditScore Geography  Gender  Age  \
# 0        1.0      0.0    0.0    15634602          619    France       0   42
# 1        0.0      0.0    1.0    15647311          608     Spain       0   41
# 2        1.0      0.0    0.0    15619304          502    France       0   42
# 3        1.0      0.0    0.0    15701354          699    France       0   39
# 4        0.0      0.0    1.0    15737888          850     Spain       0   43
# ...      ...      ...    ...         ...          ...       ...     ...  ...
# 9995     1.0      0.0    0.0    15606229          771    France       1   39
# 9996     1.0      0.0    0.0    15569892          516    France       1   35
# 9997     1.0      0.0    0.0    15584532          709    France       0   36
# 9998     0.0      1.0    0.0    15682355          772   Germany       1   42
# 9999     1.0      0.0    0.0    15628319          792    France       0   28
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

X=data
